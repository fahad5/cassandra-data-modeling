# %% [markdown]
# # Part I. ETL Pipeline for Pre-Processing the Files

# %% [markdown]
# ## PLEASE RUN THE FOLLOWING CODE FOR PRE-PROCESSING THE FILES

# %% [markdown]
# #### Import Python packages

# %%
# Import Python packages 
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv
from prettytable import PrettyTable

# %% [markdown]
# #### Creating list of filepaths to process original event csv data files

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('event_data/*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv = combined_csv[['artist','firstName','gender','itemInSession','lastName','length', 'level','location','sessionId','song','userId']]
combined_csv.dropna(inplace=True)
combined_csv
#export to csv
combined_csv.to_csv( "event_datafile_new.csv", index=False, encoding='utf-8-sig')

# %%
# Get a list of all file paths
filepath = os.getcwd() + '/event_data/'
print(filepath)
for root, dirs, files in os.walk(filepath):
    file_path_list = glob.glob(os.path.join(root,'*'))
# Out:
# /Users/fahadalajmi/Downloads/project/event_data/

# %% [markdown]
# #### Processing the files to create the data file csv that will be used for Apache Casssandra tables

# %%
full_data_rows_list = []
for f in file_path_list:
    with open(f, 'r', encoding = 'utf8', newline='') as csvfile: 
        csvreader = csv.reader(csvfile) 
        next(csvreader)
        for line in csvreader:
            full_data_rows_list.append(line) 

# Create subset of event data to insert into Apache Cassandra tables
csv.register_dialect('myDialect', quoting=csv.QUOTE_ALL, skipinitialspace=True)

with open('event_datafile_new.csv', 'w', encoding = 'utf8', newline='') as f:
    writer = csv.writer(f, dialect='myDialect')
    writer.writerow(['artist','firstName','gender','itemInSession','lastName','length',\
                'level','location','sessionId','song','userId'])
    for row in full_data_rows_list:
        if (row[0] == ''):
            continue
        writer.writerow((row[0], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[12], row[13], row[16]))

# %%
# check the number of rows in your csv file
with open('event_datafile_new.csv', 'r', encoding = 'utf8') as f:
    print(sum(1 for line in f))
# Out:
# 94

# %% [markdown]
# # Part II. Complete the Apache Cassandra coding portion of your project.
#
# ## Now you are ready to work with the CSV file titled <font color=red>event_datafile_new.csv</font>, located within the Workspace directory.  The event_datafile_new.csv contains the following columns:
# - artist
# - firstName of user
# - gender of user
# - item number in session
# - last name of user
# - length of the song
# - level (paid or free song)
# - location of the user
# - sessionId
# - song title
# - userId
#
# The image below is a screenshot of what the denormalized data should appear like in the <font color=red>**event_datafile_new.csv**</font> after the code above is run:<br>
#
# <img src="images/image_event_datafile_new.jpg">

# %% [markdown]
# ## Begin writing your Apache Cassandra code in the cells below

# %% [markdown]
# #### Creating a Cluster

# %%
from cassandra.cluster import Cluster

# make a connection to a Cassandra instance your local machine 
cluster = Cluster(['127.0.0.1'])

# establish connection and begin executing queries, need a session
session = cluster.connect()

# %% [markdown]
# #### Create Keyspace

# %%
try:
    session.execute("""
        CREATE KEYSPACE IF NOT EXISTS sparkify 
        WITH REPLICATION = 
        { 'class' : 'SimpleStrategy', 'replication_factor' : 1 }
    """)
except Exception as e:
    print(e)

# %% [markdown]
# #### Set Keyspace

# %%
# TO-DO: Set KEYSPACE to the keyspace specified above
try:
    session.set_keyspace('sparkify')
except Exception as e:
    print(e)

# %% [markdown]
# ### Now we need to create tables to run the following queries. Remember, with Apache Cassandra you model the database tables on the queries you want to run.

# %% [markdown]
# ## Create queries to ask the following three questions of the data
#
# ### 1. Give me the artist, song title and song's length in the music app history that was heard during  sessionId = 338, and itemInSession  = 4
#
#
# ### 2. Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name) for userid = 10, sessionid = 182
#
#
# ### 3. Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

# %%
## TO-DO: Query 1:  Give me the artist, song title and song's length in the music app history that was heard during \
## sessionId = 338, and itemInSession = 4
select_by_session_item = """
    SELECT artist, song, length
    FROM events_by_session_item
    WHERE sessionid = 338 AND iteminsession = 4;
"""

create_by_session_item = "CREATE TABLE IF NOT EXISTS events_by_session_item "
create_by_session_item = create_by_session_item + \
    "(sessionid int, iteminsession int, artist text, song text, length decimal, \
    PRIMARY KEY (sessionid, iteminsession))"
try:
    session.execute(create_by_session_item)
except Exception as e:
    print(e)

# %%
# Insert data into tables
file = 'event_datafile_new.csv'

with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:
        insert_by_session_item = """
            INSERT INTO events_by_session_item (sessionid, iteminsession, artist, song, length)
        """
        insert_by_session_item = insert_by_session_item + " VALUES (%s, %s, %s, %s, %s)"
        try:
            session.execute(
                insert_by_session_item,
                (int(line[8]), int(line[3]), line[0], line[9], float(line[5]))
            )
        except Exception as e:
            print(e)

# %% [markdown]
# #### Do a SELECT to verify that the data have been inserted into each table

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table
# rows = session.execute("""SELECT artist, song_title, song_length FROM session_songs WHERE sessionId = 338 AND itemInSession = 4""")

# for row in rows:
#     print(row.artist, row.song_title, row.song_length)
    
    
    
try:
    rows = session.execute(select_by_session_item)
except Exception as e:
    print(e)
t = PrettyTable(["Artist", "Song", "Length"])
for row in rows:
    t.add_row([row.artist, row.song, str(round(row.length, 2)) + " secs"])
print("Table 1. Song Info for Session ID: 338, Item: 4")
print(t)
# Out:
# Table 1. Song Info for Session ID: 338, Item: 4
# +-----------+---------------------------------+-------------+
# |   Artist  |               Song              |    Length   |
# +-----------+---------------------------------+-------------+
# | Faithless | Music Matters (Mark Knight Dub) | 495.31 secs |
# +-----------+---------------------------------+-------------+

# %% [markdown]
# ### COPY AND REPEAT THE ABOVE THREE CELLS FOR EACH OF THE THREE QUESTIONS

# %%
## TO-DO: Query 2: Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name)\
## for userid = 10, sessionid = 182

select_by_user_session_item = """
    SELECT artist, song, firstname, lastname
    FROM events_by_user_session_item
    WHERE userid = 10 AND sessionid = 182;
"""

create_by_user_session_item = "CREATE TABLE IF NOT EXISTS events_by_user_session_item "
create_by_user_session_item = create_by_user_session_item + \
    "(userid int, sessionid int, iteminsession int, artist text, song text, \
    firstname text, lastname text, PRIMARY KEY ((userid, sessionid), iteminsession))"
try:
    session.execute(create_by_user_session_item)
except Exception as e:
    print(e)

# %%
temp = pd.read_csv(file)
temp.head()
# Out:
#         artist firstName gender  itemInSession  lastName     length level  \
# 0     Harmonia      Ryan      M              0     Smith  655.77751  free
# 1  The Prodigy      Ryan      M              1     Smith  260.07465  free
# 2        Train      Ryan      M              2     Smith  205.45261  free
# 3  Sony Wonder    Samuel      M              0  Gonzalez  218.06975  free
# 4    Van Halen     Tegan      F              2    Levine  289.38404  paid
#
#                                location  sessionId  \
# 0    San Jose-Sunnyvale-Santa Clara, CA        583
# 1    San Jose-Sunnyvale-Santa Clara, CA        583
# 2    San Jose-Sunnyvale-Santa Clara, CA        583
# 3  Houston-The Woodlands-Sugar Land, TX        597
# 4           Portland-South Portland, ME        602
#
#                                              song  userId
# 0                                   Sehr kosmisch    26.0
# 1                                 The Big Gundown    26.0
# 2                                        Marry Me    26.0
# 3                                       Blackbird    61.0
# 4  Best Of Both Worlds (Remastered Album Version)    80.0

# %%
file = 'event_datafile_new.csv'

with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:
        insert_by_user_session_item = """
            INSERT INTO events_by_user_session_item (
                userid, sessionid, iteminsession, artist, song, firstname, lastname
            )
        """
        insert_by_user_session_item = insert_by_user_session_item + " VALUES (%s, %s, %s, %s, %s, %s, %s)"
        try:
            session.execute(
                insert_by_user_session_item,
                (int(line[10]), int(line[8]), int(line[3]), line[0], line[9], line[1], line[4])
            )
        except Exception as e:
            print(e)
# Out:
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '61.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '43.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '60.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '60.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '53.0'
# invalid literal for int() with base 10: '51.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '51.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '53.0'
# invalid literal for int() with base 10: '63.0'
# invalid literal for int() with base 10: '51.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '89.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '89.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '35.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '76.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '76.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '97.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '63.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '23.0'
# invalid literal for int() with base 10: '23.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '83.0'
# invalid literal for int() with base 10: '76.0'
# invalid literal for int() with base 10: '6.0'
# invalid literal for int() with base 10: '6.0'
# invalid literal for int() with base 10: '6.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '42.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '6.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '64.0'
# invalid literal for int() with base 10: '95.0'
# invalid literal for int() with base 10: '95.0'
# invalid literal for int() with base 10: '95.0'
# invalid literal for int() with base 10: '95.0'
# invalid literal for int() with base 10: '47.0'
# invalid literal for int() with base 10: '47.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '60.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '67.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '55.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '55.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '14.0'
# invalid literal for int() with base 10: '99.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '99.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '13.0'
# invalid literal for int() with base 10: '13.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '6.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '6.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '18.0'
# invalid literal for int() with base 10: '18.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '100.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '18.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '80.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '53.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '14.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '14.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '83.0'
# invalid literal for int() with base 10: '40.0'
# invalid literal for int() with base 10: '40.0'
# invalid literal for int() with base 10: '79.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '35.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '35.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '35.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '61.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '61.0'
# invalid literal for int() with base 10: '78.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '8.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '77.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '77.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '29.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '86.0'
# invalid literal for int() with base 10: '99.0'
# invalid literal for int() with base 10: '43.0'
# invalid literal for int() with base 10: '43.0'
# invalid literal for int() with base 10: '43.0'
# invalid literal for int() with base 10: '6.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '51.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '51.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '25.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# invalid literal for int() with base 10: '44.0'
# ...
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '15.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '32.0'
# invalid literal for int() with base 10: '54.0'
# invalid literal for int() with base 10: '54.0'
# invalid literal for int() with base 10: '91.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '73.0'
# invalid literal for int() with base 10: '86.0'
# invalid literal for int() with base 10: '86.0'
# invalid literal for int() with base 10: '86.0'
# invalid literal for int() with base 10: '86.0'
# invalid literal for int() with base 10: '86.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '24.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '57.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '92.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '30.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '74.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '92.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '92.0'
# invalid literal for int() with base 10: '92.0'
# invalid literal for int() with base 10: '92.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '12.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '61.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '43.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '50.0'
# invalid literal for int() with base 10: '26.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '101.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '88.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '36.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '85.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '78.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '78.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '33.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '33.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '33.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '91.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '91.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '49.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '16.0'
# invalid literal for int() with base 10: '5.0'

# %%
# Query 2: Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name)\
# for userid = 10, sessionid = 182
rows = session.execute("""
                            select artist , song , first_name , last_name
                            from event_log
                            where user_id = 10 and session_id = 182
                            order by item_in_session 

""")
for row in rows:
    print (row.artist , row.song , row.first_name , row.last_name)

# %%
# Query 3: Give me every user name (first and last) in my music app history who listened to 
# the song 'All Hands Against His Own'
session.execute("""
                    create table if not exists song_users (
                    song text, user_id int, first_name text, last_name text, 
                    primary key (song, user_id))
""")

# %%
file = 'event_datafile_new.csv'
df = pd.read_csv(file, usecols=[1, 4, 9, 10])
df.drop_duplicates(inplace=True)

for ix, row in df.iterrows():
    query = "INSERT INTO song_users (song, user_id, first_name, last_name)"
    query = query + " VALUES (%s, %s, %s, %s)"
    session.execute(query, (row['song'], row['userId'], row['firstName'], row['lastName']))
# Out:
# ---------------------------------------------------------------------------
# InvalidRequest                            Traceback (most recent call last)
# <ipython-input-106-dde19d1d5a2d> in <module>
#       6     query = "INSERT INTO song_users (song, user_id, first_name, last_name)"
#       7     query = query + " VALUES (%s, %s, %s, %s)"
# ----> 8     session.execute(query, (row['song'], row['userId'], row['firstName'], row['lastName']))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-darwin.so in cassandra.cluster.Session.execute()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-darwin.so in cassandra.cluster.ResponseFuture.result()
#
# InvalidRequest: Error from server: code=2200 [Invalid query] message="Invalid FLOAT constant (26.0) for "user_id" of type int"

# %%
rows = session.execute("""SELECT first_name, last_name FROM song_users WHERE song = 'All Hands Against His Own'""")

for row in rows:
    print( row.first_name, row.last_name )

# %% [markdown]
# ### Drop the tables before closing out the sessions

# %%
## TO-DO: Drop the table before closing out the sessions

# %% [markdown]
# ### Close the session and cluster connection¶

# %%
session.shutdown()
cluster.shutdown()
